# %%
# PASSO 1 => Criar df com a base de dados e extrair os códigos de produto e local em uma lista única para cada tipo de código

import tabula

inventario_df = tabula.read_pdf('Inventário de Estoque.PDF', pages='all')

lista_codProduto = []
lista_codLocal = []

for tabelas in inventario_df:
    for codProduto in tabelas['Cód.Int. Ref.Fabr.']:
        separar_codP = codProduto.split()
        lista_codProduto.append(separar_codP[1])
    for codLocal in tabelas['UN Local']:
        codLocal = codLocal.replace('13','17')
        codLocal = codLocal.replace('PC ','')
        codLocal = codLocal.replace('JG ','')
        lista_codLocal.append(codLocal)

print(lista_codLocal)
print(len(lista_codLocal))
print(lista_codProduto)
print(len(lista_codProduto))
# Out:
# ['17.01.A.01', '17.01.A.02', '17.01.A.03', '17.01.A.04', '17.01.A.05', '17.01.A.06', '17.01.B.01', '17.01.B.02', '17.01.B.03', '17.01.B.04', '17.01.B.05', '17.01.B.06', '17.01.C.01', '17.01.C.02', '17.01.C.03', '17.01.C.04', '17.01.C.05', '17.01.C.06', '17.01.D.01', '17.01.D.03', '17.01.D.04', '17.01.D.05', '17.01.D.06', '17.01.E.01', '17.01.E.02', '17.01.E.03', '17.01.E.04', '17.01.E.05', '17.01.E.05', '17.01.E.05', '17.01.E.05', '17.01.E.06', '17.01.F.01', '17.01.F.02', '17.01.F.03', '17.01.F.04', '17.01.F.05', '17.01.F.05', '17.01.F.06', '17.01.G.01', '17.01.G.02', '17.01.G.03', '17.01.G.04', '17.01.G.05', '17.01.G.06', '17.01.H.01', '17.01.H.02', '17.01.H.02', '17.01.H.03', '17.01.H.04', '17.01.H.04', '17.01.H.05', '17.01.H.06', '17.01.H.06', '17.01.I.01', '17.01.I.02', '17.01.I.03', '17.01.I.04', '17.01.I.05', '17.01.I.06', '17.01.J.01', '17.01.J.01', '17.01.J.02', '17.01.J.03', '17.01.J.04', '17.01.J.05', '17.01.J.06', '17.01.K.01', '17.01.K.01', '17.01.K.03', '17.01.K.05', '17.01.K.05', '17.01.L.01', '17.01.L.01', '17.01.L.01', '17.01.L.02', '17.01.L.02', '17.01.L.03', '17.01.L.03', '17.01.L.04', '17.01.L.04', '17.01.L.05', '17.01.L.06', '17.01.L.06', '17.01.M.01', '17.01.M.02', '17.01.M.03', '17.01.M.03', '17.01.M.04', '17.01.M.05', '17.01.M.05', '17.01.M.06', '17.01.M.06', '17.02..A.01', '17.02.A.02', '17.02.A.03', '17.02.A.04', '17.02.A.05', '17.02.A.06', '17.02.B.01', '17.02.B.02', '17.02.B.03', '17.02.B.04', '17.02.B.05', '17.02.B.06', '17.02.C.01', '17.02.C.02', '17.02.C.03', '17.02.C.04', '17.02.C.05', '17.02.C.06', '17.02.C.06', '17.02.D.01', '17.02.D.02', '17.02.D.03', '17.02.D.04', '17.02.D.05', '17.02.D.06', '17.02.E.01', '17.02.E.02', '17.02.E.03', '17.02.E.05', '17.02.E.06', '17.02.F.01', '17.02.F.02', '17.02.F.03
', '15270-KITCIA', '15271-KITCIA', '15437-KITCIA', '15438-KITCIA', '15483-KITCIA', '15484-KITCIA', '15011-KIT', '15261-KITCIA', '15264-KITCIA', '15265-KITCIA', '15268-KITCIA', '15269-KITCIA', '267-CECARELLI', '250-CECCARELLI', '2167013', '524455JH', 'CWB18410', '10854KITCIA', '2092102', '2091165', '2091166', '217-CICCARELLI', '218-CICARRELI', '251-CICCARELLI', '2093084', '287-CICCARELLO', '2093086', '7GM86', '2093087', '8343259', '266-CICCARELLI', '2094031', '2092042', '428-CICCARELLI', '2093052', '7GM79E', '2090006', '2093045', '2092011', '2093019', '2093021', '2093022', '8343314', '3FT35', '578502JH', '266-CICARELLI', '1VW14', '2091002', '2093146', '119', '2092215', '2092003', '2092066', '2094125', '2094126', '2132063', '2093177', '2093176', 'CWB17920', 'CWB19415', '37955JH', '2091036', '2092064']
# 321

# %%
# itens repetidos nas listas

from collections import defaultdict

keys = defaultdict(list)

# Percorre todos os elementos da lista:
for key, value in enumerate(lista_codLocal):

    # Adiciona o índice do valor na lista de índices:
    keys[value].append(key)

# Exibe o resultado:
for value in keys:
    if len(keys[value]) > 1:
        print(value, keys[value])
# Out:
# 17.01.E.05 [27, 28, 29, 30]
# 17.01.F.05 [36, 37]
# 17.01.H.02 [46, 47]
# 17.01.H.04 [49, 50]
# 17.01.H.06 [52, 53]
# 17.01.J.01 [60, 61]
# 17.01.K.01 [67, 68]
# 17.01.K.05 [70, 71]
# 17.01.L.01 [72, 73, 74]
# 17.01.L.02 [75, 76]
# 17.01.L.03 [77, 78]
# 17.01.L.04 [79, 80]
# 17.01.L.06 [82, 83]
# 17.01.M.03 [86, 87]
# 17.01.M.05 [89, 90]
# 17.01.M.06 [91, 92]
# 17.02.C.06 [110, 111]

# %%
print(lista_codProduto[82], lista_codProduto[83])
# Out:
# 8131011 AR89

# %%
# PASSO 3 => Automatizar a pesquisa dos códigos no Symplex / Automatizar a alterção dos códigos de local

#     IDEIA DE PROCESSO
import pyautogui as py
import time

py.FAILSAFE = True
# clicar no Symplex na barra de tarefa
time.sleep(2)
py.click(x=461, y=741)
# clicar em alterar cadastro
time.sleep(2)
py.click(x=609, y=152)

lista = lista_codProduto[320:]
lista2 = lista_codLocal[320:]

# clicar em editar
#     *começar loop* obs: colocar tempo de execuçao
for i, cod in enumerate(lista):
    py.write(cod)
    py.press("enter")
    time.sleep(2)
    py.click(x=880, y=434, clicks=2)
    py.write(lista2[i])
    time.sleep(2)

    py.click(x=944, y=666)
    time.sleep(2)

#     clicar na busca
#     escrever codigo produto
#     pressionar enter
#     selecionar codigo local atual
#     escrever codigo local novo
#     tratar janela de alerta com enter
#     clicar em salvar
#     *fim do loop*

# %%
import time
import pyautogui as py
# time.sleep(5)
# print(py.position())


for i, codg in enumerate(lista_codLocal):
    if '17.04.M.05' in codg:
        print(i)

print(lista_codProduto[320])
# Out:
# 319
# 2092064
